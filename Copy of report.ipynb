# %%
import polars as pl
from plotnine import *
(pl.DataFrame({
    "Knowledge": ["Without Python", "With Python"],
    "Power": [0.5, 99.5]
    })
>> ggplot(aes(x="Knowledge", y="Power"))
    + geom_col()
    + theme_minimal()
n)

# %% [markdown]
# #*italicised text*

# %% [markdown]
# 1- dnf
# 2-fjke
# 3-jkej

# %%
quarto render "/content/drive/MyDrive/Colab Notebooks/report.ipynb"
# Out:
#   File "/tmp/ipykernel_15215/599198938.py", line 1
#     quarto render "/content/drive/MyDrive/Colab Notebooks/report.ipynb"
#            ^
# SyntaxError: invalid syntax
